# %% [markdown]
# # Jupyter notebook course 6

# %% [markdown]
# In this jupyter notebook you will find all of the final presentation for the course 6 "Data science"

# %% [markdown]
# ## Programming languages
# 1. Python
# 2. R Language
# 3. SQL
# 4. Others

# %% [markdown]
# ## Data science libraries
# 1. Scientific computer libraries in python
# 2. Visualization libraries in python
# 3. High-Level machine learning and Deep learning

# %% [markdown]
# ## Data sciense tools
# | Tool                      | Description           |
# | ---------                 | -----------           |
# | MySQL                     | Data management tool  |
# | PostreSQL                 | Data management tool  |
# | cassandra                 | Data management tool  |
# | elasticsearch             | Data management tool  |
# | ceph                      | Data management tool  |
# | CouchDB                   | Data management tool  |
# | mongoDB                   | Data management tool  |
# | Hadoop                    | Data management tool  |
# | Jupyter                   | Operating System tool |
# | RStudio                   | Operating System tool |
# | Pycharm                   | Operating System tool |
# | Spyder                    | Operating System tool |
# | Microsoft Visual Studio   | Operating System tool |
# | Anaconda navigator        | Operating System tool |
# | And others..              | ...                   |

# %%
# Arithmetical expression
(10+5)*4
# Out:
# Running cells with 'c:\Users\MATIAS\AppData\Local\Programs\Python\Python312\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/MATIAS/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# Minutes to hours
hours = 5
minutes = hours / 60

# %%
# Objects list
object = {}
print(object)

# %% [markdown]
# # Author
# Matias Riva
